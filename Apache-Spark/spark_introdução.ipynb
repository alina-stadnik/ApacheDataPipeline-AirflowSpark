# %% [markdown]
# ## Apache Spark - Introdução

# %% [markdown]
# ### [Apache Spark](https://spark.apache.org/)
#
# Apache Spark é uma plataforma de computação em *cluster* que fornece uma API para programação distribuída para processamento de dados em larga escala, semelhante ao modelo *MapReduce*, mas projetada para ser rápida para consultas interativas e algoritmos iterativos.
#
# O Spark permite que você distribua dados e tarefas em clusters com vários nós. Imagine cada nó como um computador separado. A divisão dos dados torna mais fácil o trabalho com conjuntos de dados muito grandes porque cada nó funciona processa apenas uma parte parte do volume total de dados.
#
# O Spark é amplamente utilizado em projetos analíticos nas seguintes frentes:
#
# - Preparação de dados
# - Modelos de machine learning
# - Análise de dados em tempo real

# %% [markdown]
# ### [PySpark](https://spark.apache.org/docs/3.1.2/api/python/index.html)
#
# PySpark é uma interface para Apache Spark em Python. Ele não apenas permite que você escreva aplicativos Spark usando APIs Python, mas também fornece o *shell* PySpark para analisar interativamente seus dados em um ambiente distribuído. O PySpark oferece suporte à maioria dos recursos do Spark, como Spark SQL, DataFrame, Streaming, MLlib (Machine Learning) e Spark Core.
#
# <center><img src="https://caelum-online-public.s3.amazonaws.com/2273-introducao-spark/01/img-001.png"/></center>
#
# #### Spark SQL e DataFrame
#
# Spark SQL é um módulo Spark para processamento de dados estruturados. Ele fornece uma abstração de programação chamada DataFrame e também pode atuar como mecanismo de consulta SQL distribuído.
#
# #### Spark Streaming
#
# Executando em cima do Spark, o recurso de *streaming* no Apache Spark possibilita o uso de poderosas aplicações interativas e analíticas em *streaming* e dados históricos, enquanto herda a facilidade de uso do Spark e as características de tolerância a falhas.
#
# #### Spark MLlib
#
# Construído sobre o Spark, MLlib é uma biblioteca de aprendizado de máquina escalonável que fornece um conjunto uniforme de APIs de alto nível que ajudam os usuários a criar e ajustar *pipelines* de aprendizado de máquina práticos.
#
# #### Spark Core
#
# Spark Core é o mecanismo de execução geral subjacente para a plataforma Spark sobre o qual todas as outras funcionalidades são construídas. Ele fornece um RDD (*Resilient Distributed Dataset*) e recursos de computação na memória.

# %% [markdown]
# ## Utilizando o Spark no Google Colab

# %%
# instalar as dependências
# !apt-get update -qq
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.1.2/spark-3.1.2-bin-hadoop2.7.tgz
# !tar xf spark-3.1.2-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
# variável de ambiente
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop2.7"

# %%
import findspark
findspark.init()

# %% [markdown]
# # Carregamento de Dados
# ---

# %% [markdown]
# ## [SparkSession](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.SparkSession.html)
#
# O ponto de entrada para programar o Spark com a API Dataset e DataFrame.
#
# Uma SparkSession pode ser utilizada para criar DataFrames, registrar DataFrames como tabelas, executar consultas SQL em tabelas, armazenar em cache e ler arquivos parquet. Para criar uma SparkSession, use o seguinte padrão de construtor:

# %%
#from pyspark.sql import SparkSession

#spark = SparkSession.builder \
#    .master('local[*]') \
#    .appName("Iniciando com Spark") \
#    .getOrCreate()

#spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5dc8ed5e16c5:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Iniciando com Spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Acessando o [Spark UI](https://spark.apache.org/docs/3.1.2/web-ui.html) (Google Colab)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
     .master('local[*]')\
    .appName("Iniciando com Spark")\
    .config('spark.ui.port', '4050')\
    .getOrCreate()

# %% [markdown]
# [Site ngrok](https://ngrok.com)

# %%
# !wget -q https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
# !pip install pyngrok
from pyngrok import ngrok

# %%
#!ngrok authtoken 'ADD-AUTENTICADOR'

# %%
# ngrok.connect('')

# %% [markdown]
# ## DataFrames com Spark
#
#
# ### Interfaces Spark
#
# Existem três interfaces principais do Apache Spark que você deve conhecer: Resilient Distributed Dataset, DataFrame e Dataset.
#
# - **Resilient Distributed Dataset**: A primeira abstração do Apache Spark foi o Resilient Distributed Dataset (RDD). É uma interface para uma sequência de objetos de dados que consiste em um ou mais tipos localizados em uma coleção de máquinas (um cluster). Os RDDs podem ser criados de várias maneiras e são a API de “nível mais baixo” disponível. Embora esta seja a estrutura de dados original do Apache Spark, você deve se concentrar na API DataFrame, que é um superconjunto da funcionalidade RDD. A API RDD está disponível nas linguagens Java, Python e Scala.
#
# - **DataFrame**: Trata-se de um conceito similar ao DataFrame que você pode estar familiarizado como o pacote pandas do Python e a linguagem R . A API DataFrame está disponível nas linguagens Java, Python, R e Scala.
#
# - **Dataset**: uma combinação de DataFrame e RDD. Ele fornece a interface digitada que está disponível em RDDs enquanto fornece a conveniência do DataFrame. A API Dataset está disponível nas linguagens Java e Scala.
#
# Em muitos cenários, especialmente com as otimizações de desempenho incorporadas em DataFrames e Datasets, não será necessário trabalhar com RDDs. Mas é importante entender a abstração RDD porque:
#
# - O RDD é a infraestrutura subjacente que permite que o Spark seja executado com tanta rapidez e forneça a linhagem de dados.
#
# - Se você estiver mergulhando em componentes mais avançados do Spark, pode ser necessário usar RDDs.
#
# - As visualizações na Spark UI fazem referência a RDDs.

# %%
data = [('Zeca','35'), ('Eva', '29')]
colNames = ['Nome', 'Idade']

# %%
df = spark.createDataFrame(data, colNames)

# %%
df
# Out:
# DataFrame[Nome: string, Idade: string]

# %%
df.show()
# Out:
# +----+-----+
# |Nome|Idade|
# +----+-----+
# |Zeca|   35|
# | Eva|   29|
# +----+-----+

# %%
df.toPandas()
# Out:
#    Nome Idade
# 0  Zeca    35
# 1   Eva    29

# %% [markdown]
# ## Projeto
#
# O objetivo desse projeto consiste em ler, manipular, tratar e salvar um conjunto de dados volumosos utilizando como ferramenta o Spark.

# %% [markdown]
# ## Carregamento de dados
#
# ### Dados Públicos CNPJ
# #### Receita Federal
#
# > [Empresas](https://caelum-online-public.s3.amazonaws.com/2273-introducao-spark/01/empresas.zip)
# >
# > [Estabelecimentos](https://caelum-online-public.s3.amazonaws.com/2273-introducao-spark/01/estabelecimentos.zip)
# >
# > [Sócios](https://caelum-online-public.s3.amazonaws.com/2273-introducao-spark/01/socios.zip)
#
# [Fonte original dos dados](https://www.gov.br/receitafederal/pt-br/assuntos/orientacao-tributaria/cadastros/consultas/dados-publicos-cnpj)
#
# ---
# [property SparkSession.read](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.SparkSession.read.html)
#
# [DataFrameReader.csv(*args)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrameReader.csv.html)

# %% [markdown]
# ### Montando o drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Carregando os dados das empresas

# %%
import zipfile

# %%
empresaspath = 'spark/empresas'
empresas = spark.read.csv(empresaspath, sep=';', inferSchema=True)

# %%
empresas.count()
# Out:
# 4585679

# %% [markdown]
# ### Carregando os dados dos estabelecimentos

# %%
estabpath = 'spark/estabelecimentos'

# %%
estabelecimentos = spark.read.csv(estabpath, sep=';', inferSchema=True)

# %%
estabelecimentos.count()
# Out:
# 4836219

# %% [markdown]
# ### Carregando os dados dos sócios

# %%
sociospath = 'spark/socios'

# %%
socios = spark.read.csv(sociospath, sep=';', inferSchema=True)

# %%
socios.count()
# Out:
# 2046430

# %% [markdown]
# # Manipulando os Dados
# ---

# %% [markdown]
# ## Operações básicas

# %%
empresas.limit(5).toPandas()
# Out:
#     _c0                                                _c1   _c2  _c3  \
# 0   306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA  2240   49
# 1  1355                         BRASILEIRO & OLIVEIRA LTDA  2062   49
# 2  4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...  3034   32
# 3  5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS  2135   50
# 4  6846                         BADU E FILHOS TECIDOS LTDA  2062   49
#
#        _c4  _c5   _c6
# 0     0,00    1  None
# 1     0,00    5  None
# 2     0,00    5  None
# 3     0,00    5  None
# 4  4000,00    1  None

# %% [markdown]
# ### Renomeando as colunas do DataFrame (dicionário do nome das colunas estão no link)

# %%
empresasColNames = ['cnpj_basico', 'razao_social_nome_empresarial', 'natureza_juridica', 'qualificacao_do_responsavel', 'capital_social_da_empresa', 'porte_da_empresa', 'ente_federativo_responsavel']

# %%
for index, colName in enumerate(empresasColNames):
  empresas = empresas.withColumnRenamed(f'_c{index}', colName)

empresas.columns
# Out:
# ['cnpj_basico',
#  'razao_social_nome_empresarial',
#  'natureza_juridica',
#  'qualificacao_do_responsavel',
#  'capital_social_da_empresa',
#  'porte_da_empresa',
#  'ente_federativo_responsavel']

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
estabsColNames = ['cnpj_basico', 'cnpj_ordem', 'cnpj_dv', 'identificador_matriz_filial', 'nome_fantasia', 'situacao_cadastral', 'data_situacao_cadastral', 'motivo_situacao_cadastral', 'nome_da_cidade_no_exterior', 'pais', 'data_de_inicio_atividade', 'cnae_fiscal_principal', 'cnae_fiscal_secundaria', 'tipo_de_logradouro', 'logradouro', 'numero', 'complemento', 'bairro', 'cep', 'uf', 'municipio', 'ddd_1', 'telefone_1', 'ddd_2', 'telefone_2', 'ddd_do_fax', 'fax', 'correio_eletronico', 'situacao_especial', 'data_da_situacao_especial']

# %%
for index, colName in enumerate(estabsColNames):
  estabelecimentos = estabelecimentos.withColumnRenamed(f'_c{index}', colName)

estabelecimentos.columns
# Out:
# ['cnpj_basico',
#  'cnpj_ordem',
#  'cnpj_dv',
#  'identificador_matriz_filial',
#  'nome_fantasia',
#  'situacao_cadastral',
#  'data_situacao_cadastral',
#  'motivo_situacao_cadastral',
#  'nome_da_cidade_no_exterior',
#  'pais',
#  'data_de_inicio_atividade',
#  'cnae_fiscal_principal',
#  'cnae_fiscal_secundaria',
#  'tipo_de_logradouro',
#  'logradouro',
#  'numero',
#  'complemento',
#  'bairro',
#  'cep',
#  'uf',
#  'municipio',
#  'ddd_1',
#  'telefone_1',
#  'ddd_2',
#  'telefone_2',
#  'ddd_do_fax',
#  'fax',
#  'correio_eletronico',
#  'situacao_especial',
#  'data_da_situacao_especial']

# %%
estabelecimentos.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
#
#        nome_fantasia  situacao_cadastral  data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8                 20011029
# 1               None                   8                 20081231
# 2               None                   8                 19971231
# 3               None                   8                 20081231
# 4  EMBROIDERY & GIFT                   8                 19980429
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ...  municipio  \
# 0                          1                       None   NaN  ...       7107
# ...

# %%
socios.limit(5).toPandas()
# Out:
#      _c0  _c1                              _c2          _c3  _c4       _c5  \
# 0    411    2      LILIANA PATRICIA GUASTAVINO  ***678188**   22  19940725
# 1    411    2             CRISTINA HUNDERTMARK  ***637848**   28  19940725
# 2   5813    2  CELSO EDUARDO DE CASTRO STEPHAN  ***786068**   49  19940516
# 3   5813    2        EDUARDO BERRINGER STEPHAN  ***442348**   49  19940516
# 4  14798    2              HANNE MAHFOUD FADEL  ***760388**   49  19940609
#
#    _c6          _c7   _c8  _c9  _c10
# 0  NaN  ***000000**  None    0     7
# 1  NaN  ***000000**  None    0     7
# 2  NaN  ***000000**  None    0     8
# 3  NaN  ***000000**  None    0     5
# 4  NaN  ***000000**  None    0     8

# %%
sociosColNames = ['cnpj_basico', 'identificador_de_socio', 'nome_do_socio_ou_razao_social', 'cnpj_ou_cpf_do_socio', 'qualificacao_do_socio', 'data_de_entrada_sociedade', 'pais', 'representante_legal', 'nome_do_representante', 'qualificacao_do_representante_legal', 'faixa_etaria']

# %%
for index, colName in enumerate(sociosColNames):
  socios = socios.withColumnRenamed(f'_c{index}', colName)

socios.columns
# Out:
# ['cnpj_basico',
#  'identificador_de_socio',
#  'nome_do_socio_ou_razao_social',
#  'cnpj_ou_cpf_do_socio',
#  'qualificacao_do_socio',
#  'data_de_entrada_sociedade',
#  'pais',
#  'representante_legal',
#  'nome_do_representante',
#  'qualificacao_do_representante_legal',
#  'faixa_etaria']

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# ...

# %% [markdown]
# ## Analisando os dados
#
# [Data Types](https://spark.apache.org/docs/3.1.2/api/python/reference/pyspark.sql.html#data-types)

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0,00
# 1               2062                           49                      0,00
# 2               3034                           32                      0,00
# 3               2135                           50                      0,00
# 4               2062                           49                   4000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresas.printSchema()
# tipo de coluna do DataFrame
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: string (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
# capital_social_da_empresa está representado por uma string enquanto é na vdd um valor monetário
# possivelmente pq o separador decimal está em ,

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# ...

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: integer (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %%
# data_de_entrada_sociedade está como int e é importante alterar para o formato de data

# %%
estabelecimentos.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
#
#        nome_fantasia  situacao_cadastral  data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8                 20011029
# 1               None                   8                 20081231
# 2               None                   8                 19971231
# 3               None                   8                 20081231
# 4  EMBROIDERY & GIFT                   8                 19980429
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ...  municipio  \
# 0                          1                       None   NaN  ...       7107
# ...

# %%
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: integer (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: integer (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %% [markdown]
# Tipo de data types:
#
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/data_types.html

# %% [markdown]
# ## Modificando os tipos de dados
#
# [Functions](https://spark.apache.org/docs/3.1.2/api/python/reference/pyspark.sql.html#functions)
#
# [withColumn](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.withColumn.html)

# %% [markdown]
# ### Convertendo String ➔ Double
#
# #### `StringType ➔ DoubleType`

# %%
from pyspark.sql.types import DoubleType, StringType
from pyspark.sql import functions as f

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: string (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
# modificando , da coluna capital_social_da_empresa:
empresas = empresas.withColumn('capital_social_da_empresa', f.regexp_replace('capital_social_da_empresa', ',', '.')) # primeiro item: localiza // segundo: substitui por

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2240                           49                      0.00
# 1               2062                           49                      0.00
# 2               3034                           32                      0.00
# 3               2135                           50                      0.00
# 4               2062                           49                   4000.00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: string (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
# capital_social_da_empresa continua como string, porém quero converter para o tipo double
empresas = empresas.withColumn('capital_social_da_empresa', empresas['capital_social_da_empresa'].cast(DoubleType()))
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0          306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1         1355                         BRASILEIRO & OLIVEIRA LTDA
# 2         4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3         5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4         6846                         BADU E FILHOS TECIDOS LTDA
#
#    natureza_juridica  qualificacao_do_responsavel  capital_social_da_empresa  \
# 0               2240                           49                        0.0
# 1               2062                           49                        0.0
# 2               3034                           32                        0.0
# 3               2135                           50                        0.0
# 4               2062                           49                     4000.0
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 1                        None
# ...

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %% [markdown]
# ### Convertendo String ➔ Date
#
# #### `StringType ➔ DateType`
#
# [Datetime Patterns](https://spark.apache.org/docs/3.1.2/sql-ref-datetime-pattern.html)

# %%
df = spark.createDataFrame([(20200924,), (20201022,), (20210215,)], ['data'])
df.toPandas()
# Out:
#        data
# 0  20200924
# 1  20201022
# 2  20210215

# %%
df.printSchema()
# Out:
# root
#  |-- data: long (nullable = true)

# %%
# Primeiro transforma o valor em uma string para depois aplicar to_date
df = df.withColumn('data', f.to_date(df.data.cast(StringType()), 'yyyyMMdd'))
df.printSchema()
# Out:
# root
#  |-- data: date (nullable = true)

# %%
df.toPandas()
# Out:
#          data
# 0  2020-09-24
# 1  2020-10-22
# 2  2021-02-15

# %%
estabelecimentos.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
#
#        nome_fantasia  situacao_cadastral  data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8                 20011029
# 1               None                   8                 20081231
# 2               None                   8                 19971231
# 3               None                   8                 20081231
# 4  EMBROIDERY & GIFT                   8                 19980429
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ...  municipio  \
# 0                          1                       None   NaN  ...       7107
# ...

# %%
estabelecimentos = estabelecimentos.withColumn('data_situacao_cadastral', f.to_date(estabelecimentos.data_situacao_cadastral.cast(StringType()), 'yyyyMMdd'))
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: integer (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %%
estabelecimentos = estabelecimentos.withColumn('data_de_inicio_atividade', f.to_date(estabelecimentos.data_de_inicio_atividade.cast(StringType()), 'yyyyMMdd'))
estabelecimentos.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
#
#        nome_fantasia  situacao_cadastral data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8              2001-10-29
# 1               None                   8              2008-12-31
# 2               None                   8              1997-12-31
# 3               None                   8              2008-12-31
# 4  EMBROIDERY & GIFT                   8              1998-04-29
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ... municipio  \
# 0                          1                       None   NaN  ...      7107
# ...

# %%
estabelecimentos.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
#
#        nome_fantasia  situacao_cadastral data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8              2001-10-29
# 1               None                   8              2008-12-31
# 2               None                   8              1997-12-31
# 3               None                   8              2008-12-31
# 4  EMBROIDERY & GIFT                   8              1998-04-29
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ...  municipio  \
# 0                          1                       None   NaN  ...       7107
# ...

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                      None   NaN
# 1          ***637848**                     28                      None   NaN
# 2          ***786068**                     49                      None   NaN
# 3          ***442348**                     49                      None   NaN
# 4          ***760388**                     49                      None   NaN
#
#   representante_legal nome_do_representante  \
# ...

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: date (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %%
socios = socios.withColumn('data_de_entrada_sociedade', f.to_date(socios.data_de_entrada_sociedade.cast(StringType()), 'yyyyMMdd'))
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25   NaN
# 1          ***637848**                     28                1994-07-25   NaN
# 2          ***786068**                     49                1994-05-16   NaN
# 3          ***442348**                     49                1994-05-16   NaN
# 4          ***760388**                     49                1994-06-09   NaN
#
#   representante_legal nome_do_representante  \
# ...

# %% [markdown]
# # Seleções e consultas
# ---

# %% [markdown]
# ## Selecionando informações
#
# [DataFrame.select(*cols)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.select.html)

# %%
empresas.select('*').show(5) # seleciona todas as colunas e as 5 primeiras rows
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# ...

# %%
empresas.select('*').show(5, False) # it shows truncated by default
# Out:
# +-----------+--------------------------------------------------------------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial                                                               |natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+--------------------------------------------------------------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |306        |FRANCAMAR REFRIGERACAO TECNICA S/C LTDA                                                     |2240             |49                         |0.0                      |1               |null                       |
# ...

# %%
empresas.select('natureza_juridica', 'porte_da_empresa', 'capital_social_da_empresa').show(5)
# Out:
# +-----------------+----------------+-------------------------+
# |natureza_juridica|porte_da_empresa|capital_social_da_empresa|
# +-----------------+----------------+-------------------------+
# |             2240|               1|                      0.0|
# |             2062|               5|                      0.0|
# |             3034|               5|                      0.0|
# |             2135|               5|                      0.0|
# |             2062|               1|                   4000.0|
# +-----------------+----------------+-------------------------+
# only showing top 5 rows

# %%
# Criando uma nova coluna
socios.select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade').alias('ano_de_entrada')).show(5, False)
# Out:
# +-------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social  |faixa_etaria|ano_de_entrada|
# +-------------------------------+------------+--------------+
# |LILIANA PATRICIA GUASTAVINO    |7           |1994          |
# |CRISTINA HUNDERTMARK           |7           |1994          |
# |CELSO EDUARDO DE CASTRO STEPHAN|8           |1994          |
# |EDUARDO BERRINGER STEPHAN      |5           |1994          |
# |HANNE MAHFOUD FADEL            |8           |1994          |
# +-------------------------------+------------+--------------+
# only showing top 5 rows

# %%
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %%
estabelecimentos.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         1879           1       96                            1
# 1         2818           1       43                            1
# 2         3110           1        7                            1
# 3         3733           1       80                            1
# 4         4628           3       27                            2
#
#        nome_fantasia  situacao_cadastral data_situacao_cadastral  \
# 0     PIRAMIDE M. C.                   8              2001-10-29
# 1               None                   8              2008-12-31
# 2               None                   8              1997-12-31
# 3               None                   8              2008-12-31
# 4  EMBROIDERY & GIFT                   8              1998-04-29
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ...  municipio  \
# 0                          1                       None   NaN  ...       7107
# ...

# %%
estabelecimentos.select('nome_fantasia', 'municipio',\
                        f.year('data_de_inicio_atividade').alias('ano_de_inicio_atividade'),\
                        f.month('data_de_inicio_atividade').alias('mes_de_inicio_atividade'))\
                        .show(5, False)
# Out:
# +-----------------+---------+-----------------------+-----------------------+
# |nome_fantasia    |municipio|ano_de_inicio_atividade|mes_de_inicio_atividade|
# +-----------------+---------+-----------------------+-----------------------+
# |PIRAMIDE M. C.   |7107     |1994                   |5                      |
# |null             |7107     |1994                   |5                      |
# |null             |7107     |1994                   |5                      |
# |null             |7107     |1994                   |5                      |
# |EMBROIDERY & GIFT|7075     |1995                   |5                      |
# +-----------------+---------+-----------------------+-----------------------+
# only showing top 5 rows

# %%
data = [
    ('GISELLE PAULA GUIMARAES CASTRO', 15),
    ('ELAINE GARCIA DE OLIVEIRA', 22),
    ('JOAO CARLOS ABNER DE LOURDES', 43),
    ('MARTA ZELI FERREIRA', 24),
    ('LAUDENETE WIGGERS ROEDER', 51)
]
colNames = ['nome', 'idade']
df = spark.createDataFrame(data, colNames)
df.show(truncate=False)
# Out:
# +------------------------------+-----+
# |nome                          |idade|
# +------------------------------+-----+
# |GISELLE PAULA GUIMARAES CASTRO|15   |
# |ELAINE GARCIA DE OLIVEIRA     |22   |
# |JOAO CARLOS ABNER DE LOURDES  |43   |
# |MARTA ZELI FERREIRA           |24   |
# |LAUDENETE WIGGERS ROEDER      |51   |
# +------------------------------+-----+

# %%
df.select(f.concat_ws(', ', f.substring_index('nome', ' ', -1), f.substring_index('nome', ' ', 1)).alias('ident'),'idade').show()
# Out:
# +-----------------+-----+
# |            ident|idade|
# +-----------------+-----+
# |  CASTRO, GISELLE|   15|
# | OLIVEIRA, ELAINE|   22|
# |    LOURDES, JOAO|   43|
# |  FERREIRA, MARTA|   24|
# |ROEDER, LAUDENETE|   51|
# +-----------------+-----+

# %% [markdown]
# ## Identificando valores nulos

# %%
df = spark.createDataFrame([(1,), (2,), (3,), (None,)], ['data'])
df.toPandas() # aparece NaN
# Out:
#    data
# 0   1.0
# 1   2.0
# 2   3.0
# 3   NaN

# %%
df.show() # aqui ficou null pq é int
# Out:
# +----+
# |data|
# +----+
# |   1|
# |   2|
# |   3|
# |null|
# +----+

# %%
df = spark.createDataFrame([(1.,), (2.,), (3.,), (float('nan'),)], ['data'])
df.toPandas() # agora usando float
# Out:
#    data
# 0   1.0
# 1   2.0
# 2   3.0
# 3   NaN

# %%
df.show() # não é mais um null
# Out:
# +----+
# |data|
# +----+
# | 1.0|
# | 2.0|
# | 3.0|
# | NaN|
# +----+

# %%
df = spark.createDataFrame([('1',), ('2',), ('3',), (None,)], ['data'])
df.toPandas() # agora com string ficou None
# Out:
#    data
# 0     1
# 1     2
# 2     3
# 3  None

# %%
df.show()
# Out:
# +----+
# |data|
# +----+
# |   1|
# |   2|
# |   3|
# |null|
# +----+

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                      None   NaN
# 1          ***637848**                     28                      None   NaN
# 2          ***786068**                     49                      None   NaN
# 3          ***442348**                     49                      None   NaN
# 4          ***760388**                     49                      None   NaN
#
#   representante_legal nome_do_representante  \
# ...

# %%
socios.limit(5).show()
# pais e nome do representante estão null aqui no .show()
# Out:
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social|cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |        411|                     2|         LILIANA PATRICIA ...|         ***678188**|                   22|                     null|null|        ***000000**|                 null|                                  0|           7|
# ...

# %%
socios.select([f.count(f.when(f.isnull(colName), 1)).alias(colName) for colName in socios.columns]).show()
# f.count exige um segundo argumento para fazer a contagem
# f.when é uma função de condicional que irá contar quando o valor for nulo (f.isnull(dentro de uma determinada coluna))
# for colName in socios.columns para fazer a contagem de todas os nulos presentes nas colunas do df
# Out:
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social|cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|   pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+
# |          0|                     0|                          208|                1234|                    0|                  2046430|2038255|                  0|              1995432|                                  0|           0|
# ...

# %%
socios.limit(5).toPandas()
# país é nan e nome_do_representante é none
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                      None   NaN
# 1          ***637848**                     28                      None   NaN
# 2          ***786068**                     49                      None   NaN
# 3          ***442348**                     49                      None   NaN
# 4          ***760388**                     49                      None   NaN
#
#   representante_legal nome_do_representante  \
# ...

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: date (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %%
# pais eh int
# nome_do_representante eh string
# duas formas de mudar isso (substituir isso por algum outro valor que eu queira):

socios.na.fill(0).limit(5).toPandas() # faz isso geral, para o df inteiro (apenas para colunas numeros)
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                      None     0
# 1          ***637848**                     28                      None     0
# 2          ***786068**                     49                      None     0
# 3          ***442348**                     49                      None     0
# 4          ***760388**                     49                      None     0
#
#   representante_legal nome_do_representante  \
# ...

# %%
socios.na.fill('-').limit(5).toPandas() # nome do representando recebe o -
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                      None   NaN
# 1          ***637848**                     28                      None   NaN
# 2          ***786068**                     49                      None   NaN
# 3          ***442348**                     49                      None   NaN
# 4          ***760388**                     49                      None   NaN
#
#   representante_legal nome_do_representante  \
# ...

# %% [markdown]
# ## Ordenando os dados
#
# [DataFrame.orderBy(*cols, **kwargs)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.orderBy.html)

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                      None   NaN
# 1          ***637848**                     28                      None   NaN
# 2          ***786068**                     49                      None   NaN
# 3          ***442348**                     49                      None   NaN
# 4          ***760388**                     49                      None   NaN
#
#   representante_legal nome_do_representante  \
# ...

# %%
socios\
            .select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
            .show(5, False)
# Out:
# +-------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social  |faixa_etaria|ano_de_entrada|
# +-------------------------------+------------+--------------+
# |LILIANA PATRICIA GUASTAVINO    |7           |1994          |
# |CRISTINA HUNDERTMARK           |7           |1994          |
# |CELSO EDUARDO DE CASTRO STEPHAN|8           |1994          |
# |EDUARDO BERRINGER STEPHAN      |5           |1994          |
# |HANNE MAHFOUD FADEL            |8           |1994          |
# +-------------------------------+------------+--------------+
# only showing top 5 rows

# %%
socios\
            .select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
            .orderBy('ano_de_entrada', ascending=False)\
            .show(5, False)
# Out:
# +----------------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social           |faixa_etaria|ano_de_entrada|
# +----------------------------------------+------------+--------------+
# |KASSIANO RODRIGO KICHILESKI             |4           |2021          |
# |LEONARDO MENNA BARRETO LARANJA GONCALVES|5           |2021          |
# |MANOEL ADRIANO COSTA BARBOSA            |6           |2021          |
# |ANTONOALDO GRANGEON TRANCOSO NEVES      |5           |2021          |
# |MARIA SUELY DE MOURA                    |5           |2021          |
# +----------------------------------------+------------+--------------+
# only showing top 5 rows

# %%
# orderBy usando mais de uma coluna: passa uma lista com as colunas e pode tb configurar o ascending na ordem de cada coluna
socios\
            .select('nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
            .orderBy(['ano_de_entrada', 'faixa_etaria'], ascending=[False, False])\
            .show(5, False)
# Out:
# +-------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social  |faixa_etaria|ano_de_entrada|
# +-------------------------------+------------+--------------+
# |MARIA RAIMUNDA DOS SANTOS LANZA|9           |2021          |
# |MARIA JOSE DOMINGUES BONATO    |9           |2021          |
# |DORIS PEREIRA GOMES JAZRA      |9           |2021          |
# |NADIR BICHARA CHUAHY           |9           |2021          |
# |RAIMUNDA TORRES MARTINS        |9           |2021          |
# +-------------------------------+------------+--------------+
# only showing top 5 rows

# %%
data = [
    ('CARMINA RABELO', 4, 2010),
    ('HERONDINA PEREIRA', 6, 2009),
    ('IRANI DOS SANTOS', 12, 2010),
    ('JOAO BOSCO DA FONSECA', 3, 2009),
    ('CARLITO SOUZA', 1, 2010),
    ('WALTER DIAS', 9, 2009),
    ('BRENO VENTUROSO', 1, 2009),
    ('ADELINA TEIXEIRA', 5, 2009),
    ('ELIO SILVA', 7, 2010),
    ('DENIS FONSECA', 6, 2010)
]
colNames = ['nome', 'mes', 'ano']
df = spark.createDataFrame(data, colNames)
df.show(truncate=False)
# Out:
# +---------------------+---+----+
# |nome                 |mes|ano |
# +---------------------+---+----+
# |CARMINA RABELO       |4  |2010|
# |HERONDINA PEREIRA    |6  |2009|
# |IRANI DOS SANTOS     |12 |2010|
# |JOAO BOSCO DA FONSECA|3  |2009|
# |CARLITO SOUZA        |1  |2010|
# |WALTER DIAS          |9  |2009|
# |BRENO VENTUROSO      |1  |2009|
# |ADELINA TEIXEIRA     |5  |2009|
# |ELIO SILVA           |7  |2010|
# |DENIS FONSECA        |6  |2010|
# +---------------------+---+----+

# %%
# ordenar DataFrame dos alunos mais novos para os mais velhos
# ascending = True > ordena em ordem crescente
# ascending = False > ordena em ordem decrescente (alunos mais novos antes)
# a ordem em que são informadas as colunas para o método orderBy influencia diretamente o resultado
df.select('*').orderBy(['ano', 'mes'], ascending=[False, False]).show(truncate=False)
# Out:
# +---------------------+---+----+
# |nome                 |mes|ano |
# +---------------------+---+----+
# |IRANI DOS SANTOS     |12 |2010|
# |ELIO SILVA           |7  |2010|
# |DENIS FONSECA        |6  |2010|
# |CARMINA RABELO       |4  |2010|
# |CARLITO SOUZA        |1  |2010|
# |WALTER DIAS          |9  |2009|
# |HERONDINA PEREIRA    |6  |2009|
# |ADELINA TEIXEIRA     |5  |2009|
# |JOAO BOSCO DA FONSECA|3  |2009|
# |BRENO VENTUROSO      |1  |2009|
# +---------------------+---+----+

# %% [markdown]
# ## Filtrando os dados
#
# [DataFrame.where(condition)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.where.html) ou [DataFrame.filter(condition)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.filter.html): são similares

# %%
# quero pegar as empresas de capital social pequeno (50 reais)
empresas.where("capital_social_da_empresa==50").show(5, False)
# Out:
# +-----------+------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial       |natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |17350147   |ERIK MARCELO DOS SANTOS 42107848858 |2135             |50                         |50.0                     |1               |null                       |
# |17833214   |ALEXANDRE MACHADO LIMA 73750123772  |2135             |50                         |50.0                     |1               |null                       |
# ...

# %%
# filtro por nome do socio ou razao social
# usando filter
socios.select("nome_do_socio_ou_razao_social")\
  .filter(socios.nome_do_socio_ou_razao_social.startswith('ALINA'))\
  .limit(10)\
  .toPandas()
# Out:
#     nome_do_socio_ou_razao_social
# 0              ALINA CIRINO ALVES
# 1         ALINA CHIARADIA CARDOSO
# 2         ALINA CAMINERO TIZZIANI
# 3             ALINA GOMES BARRETO
# 4        ALINA LEAL COSTA RIBEIRO
# 5  ALINA MARIA COSTA CASTRO ALVES
# 6       ALINAURA TEIXEIRA DE LIMA
# 7        ALINA MARINHO DOS SANTOS
# 8              ALINALDO LUZ COSTA
# 9         ALINA CADORE FURLANETTO

# %%
# usando where
socios.select("nome_do_socio_ou_razao_social")\
  .where(socios.nome_do_socio_ou_razao_social.startswith('EVERTON'))\
  .where(socios.nome_do_socio_ou_razao_social.endswith('SILVA'))\
  .limit(10)\
  .toPandas()
# Out:
#   nome_do_socio_ou_razao_social
# 0      EVERTON RODRIGO DA SILVA
# 1        EVERTON ARAGAO E SILVA
# 2       EVERTON CARLOS DA SILVA
# 3       EVERTON MORETH DA SILVA
# 4            EVERTON LUIZ SILVA
# 5       EVERTON SERRAO DA SILVA
# 6   EVERTON CAVALCANTE DA SILVA
# 7     EVERTON ZACARIAS DA SILVA
# 8    EVERTON RODRIGUES DA SILVA
# 9     EVERTON DE CARVALHO SILVA

# %%
data = [
    ('CARMINA RABELO', 4, 2010),
    ('HERONDINA PEREIRA', 6, 2009),
    ('IRANI DOS SANTOS', 12, 2010),
    ('JOAO BOSCO DA FONSECA', 3, 2009),
    ('CARLITO SOUZA', 1, 2010),
    ('WALTER DIAS', 9, 2009),
    ('BRENO VENTUROSO', 1, 2009),
    ('ADELINA TEIXEIRA', 5, 2009),
    ('ELIO SILVA', 7, 2010),
    ('DENIS FONSECA', 6, 2010)
]
colNames = ['nome', 'mes', 'ano']
df = spark.createDataFrame(data, colNames)
df.show(truncate=False)
# Out:
# +---------------------+---+----+
# |nome                 |mes|ano |
# +---------------------+---+----+
# |CARMINA RABELO       |4  |2010|
# |HERONDINA PEREIRA    |6  |2009|
# |IRANI DOS SANTOS     |12 |2010|
# |JOAO BOSCO DA FONSECA|3  |2009|
# |CARLITO SOUZA        |1  |2010|
# |WALTER DIAS          |9  |2009|
# |BRENO VENTUROSO      |1  |2009|
# |ADELINA TEIXEIRA     |5  |2009|
# |ELIO SILVA           |7  |2010|
# |DENIS FONSECA        |6  |2010|
# +---------------------+---+----+

# %%
# seleção de apenas alunos nascidos no primeiro semestre de 2009
df.filter('mes<=6').filter('ano=2009').show(truncate=False)
# Out:
# +---------------------+---+----+
# |nome                 |mes|ano |
# +---------------------+---+----+
# |HERONDINA PEREIRA    |6  |2009|
# |JOAO BOSCO DA FONSECA|3  |2009|
# |BRENO VENTUROSO      |1  |2009|
# |ADELINA TEIXEIRA     |5  |2009|
# +---------------------+---+----+

# %%
# seleção de apenas alunos nascidos no primeiro semestre de 2009
df.filter('mes<=6' and 'ano=2009').show(truncate=False)
# Out:
# +---------------------+---+----+
# |nome                 |mes|ano |
# +---------------------+---+----+
# |HERONDINA PEREIRA    |6  |2009|
# |JOAO BOSCO DA FONSECA|3  |2009|
# |WALTER DIAS          |9  |2009|
# |BRENO VENTUROSO      |1  |2009|
# |ADELINA TEIXEIRA     |5  |2009|
# +---------------------+---+----+

# %%
df.filter(df.mes <= 6).filter(df.ano == 2009).show(truncate=False)
# Out:
# +---------------------+---+----+
# |nome                 |mes|ano |
# +---------------------+---+----+
# |HERONDINA PEREIRA    |6  |2009|
# |JOAO BOSCO DA FONSECA|3  |2009|
# |BRENO VENTUROSO      |1  |2009|
# |ADELINA TEIXEIRA     |5  |2009|
# +---------------------+---+----+

# %%
df.filter((df.mes <= 6) & (df.ano == 2009)).show(truncate=False)
# Out:
# +---------------------+---+----+
# |nome                 |mes|ano |
# +---------------------+---+----+
# |HERONDINA PEREIRA    |6  |2009|
# |JOAO BOSCO DA FONSECA|3  |2009|
# |BRENO VENTUROSO      |1  |2009|
# |ADELINA TEIXEIRA     |5  |2009|
# +---------------------+---+----+

# %% [markdown]
# ## O comando LIKE
#
# [Column.like(other)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.Column.like.html)

# %%
df = spark.createDataFrame([('RESTAURANTE DO RUI',), ('Juca restaurantes ltda',), ('Joca Restaurante',)], ['data'])
df.toPandas()
# Out:
#                      data
# 0      RESTAURANTE DO RUI
# 1  Juca restaurantes ltda
# 2        Joca Restaurante

# %%
# selecionar registros que tenham 'restaurante'
df.where(f.upper(df.data).like('%RESTAURANTE%')).show(truncate=False)
# f.upper string fica tudo em caps
# .like retorna um boolean que junto com .where mostra apenas o que é True
# Out:
# +----------------------+
# |data                  |
# +----------------------+
# |RESTAURANTE DO RUI    |
# |Juca restaurantes ltda|
# |Joca Restaurante      |
# +----------------------+

# %%
# selecionar registros que comecem com a palavra 'restaurante' > elimina o primeiro %
df.where(f.upper(df.data).like('RESTAURANTE%')).show(truncate=False)
# Out:
# +------------------+
# |data              |
# +------------------+
# |RESTAURANTE DO RUI|
# +------------------+

# %%
# selecionar registros que terminem com a palavra 'restaurante' > elimina o segundo %
df.where(f.upper(df.data).like('%RESTAURANTE')).show(truncate=False)
# Out:
# +----------------+
# |data            |
# +----------------+
# |Joca Restaurante|
# +----------------+

# %%
empresas\
    .select('razao_social_nome_empresarial', 'natureza_juridica', 'porte_da_empresa', 'capital_social_da_empresa')\
    .filter(f.upper(empresas['razao_social_nome_empresarial']).like('%PADARIA%'))\
    .show(15, False)
# Out:
# +---------------------------------------------------+-----------------+----------------+-------------------------+
# |razao_social_nome_empresarial                      |natureza_juridica|porte_da_empresa|capital_social_da_empresa|
# +---------------------------------------------------+-----------------+----------------+-------------------------+
# |L A MAGRINI PADARIA                                |2135             |5               |0.0                      |
# |J BATISTA DE SOUZA PADARIA LANCHONETE E MERCEARIA  |2135             |1               |0.0                      |
# |JOSE SIMON - PADARIA                               |2135             |5               |0.0                      |
# |PADARIA COPA REAL DE CAXIAS LTDA                   |2062             |1               |0.0                      |
# |MINIMERCADO PADARIA E CONFEITARIA DOCE NA BOCA LTDA|2062             |1               |0.0                      |
# ...

# %% [markdown]
# # Agregações e Junções
# ---
#
# [DataFrame.groupBy(*cols)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.groupBy.html)
#
# [DataFrame.agg(*exprs)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.agg.html)
#
# [DataFrame.summary(*statistics)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.summary.html)
#
# > Funções:
# [approx_count_distinct](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.approx_count_distinct.html) |
# [avg](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.avg.html) |
# [collect_list](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.collect_list.html) |
# [collect_set](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.collect_set.html) |
# [countDistinct](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.countDistinct.html) |
# [count](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.count.html) |
# [grouping](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.grouping.html) |
# [first](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.first.html) |
# [last](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.last.html) |
# [kurtosis](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.kurtosis.html) |
# [max](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.max.html) |
# [min](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.min.html) |
# [mean](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.mean.html) |
# [skewness](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.skewness.html) |
# [stddev ou stddev_samp](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.stddev.html) |
# [stddev_pop](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.stddev_pop.html) |
# [sum](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.sum.html) |
# [sumDistinct](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.sumDistinct.html) |
# [variance ou var_samp](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.variance.html) |
# [var_pop](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.functions.var_pop.html)

# %% [markdown]
# ## Sumarizando os dados

# %%
# possibilita utilizar estatistica descritiva

socios\
    .select(f.year('data_de_entrada_sociedade').alias('ano_de_entrada'))\
    .where('ano_de_entrada >= 2010')\
    .groupBy('ano_de_entrada')\
    .count()\
    .orderBy('ano_de_entrada', ascending=True)\
    .show()

# quantas pessoas entraram (count) em um determinado ano
# ano ordenado de forma crescente
# Out:
# +--------------+------+
# |ano_de_entrada| count|
# +--------------+------+
# |          2010| 79337|
# |          2011| 83906|
# |          2012| 80101|
# |          2013| 83919|
# |          2014| 80590|
# |          2015| 80906|
# |          2016| 81587|
# |          2017| 90221|
# |          2018| 99935|
# |          2019|118248|
# |          2020|125927|
# |          2021| 56316|
# +--------------+------+

# %%
empresas\
    .select('cnpj_basico', 'porte_da_empresa', 'capital_social_da_empresa')\
    .groupBy('porte_da_empresa')\
    .agg(
        f.avg("capital_social_da_empresa").alias("capital_social_medio"),
        f.count("cnpj_basico").alias("frequencia")
    )\
    .orderBy('porte_da_empresa', ascending=True)\
    .show()
# Out:
# +----------------+--------------------+----------+
# |porte_da_empresa|capital_social_medio|frequencia|
# +----------------+--------------------+----------+
# |            null|    8.35421888053467|      5985|
# |               1|  339994.53313506936|   3129043|
# |               3|  2601001.7677092673|    115151|
# |               5|   708660.4208249798|   1335500|
# +----------------+--------------------+----------+

# %%
# pandas describe() equivalente
empresas.select('capital_social_da_empresa').summary().show()
# Out:
# +-------+-------------------------+
# |summary|capital_social_da_empresa|
# +-------+-------------------------+
# |  count|                  4585679|
# |   mean|        503694.5478542675|
# | stddev|     2.1118691490537405E8|
# |    min|                      0.0|
# |    25%|                      0.0|
# |    50%|                   1000.0|
# |    75%|                   7000.0|
# |    max|         3.22014670262E11|
# +-------+-------------------------+

# %%
empresas.select('capital_social_da_empresa').summary('mean', 'stddev').show()
# Out:
# +-------+-------------------------+
# |summary|capital_social_da_empresa|
# +-------+-------------------------+
# |   mean|        503694.5478542675|
# | stddev|     2.1118691490537405E8|
# +-------+-------------------------+

# %%
socios.limit(5).show()
# Out:
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social|cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |        411|                     2|         LILIANA PATRICIA ...|         ***678188**|                   22|               1994-07-25|null|        ***000000**|                 null|                                  0|           7|
# ...

# %%
# média de qualificação do socio no conjunto de dados 'socios'
socios.select('qualificacao_do_socio').summary('mean').show()
# Out:
# +-------+---------------------+
# |summary|qualificacao_do_socio|
# +-------+---------------------+
# |   mean|    39.24532722839286|
# +-------+---------------------+

# %%
# agrupando e contando os mesmos cnpj_bascido e ordenando pela contagem
socios.groupBy('cnpj_basico').count().orderBy('count', ascending=False).show()
# Out:
# +-----------+-----+
# |cnpj_basico|count|
# +-----------+-----+
# |   14775280|  517|
# |    3875235|  459|
# |   25254114|  450|
# |   59527788|  394|
# |    2289157|  263|
# |    9504894|  254|
# |   36047773|  235|
# |   35540425|  201|
# |   13084349|  193|
# |    6958644|  190|
# |    1486618|  173|
# |   31977693|  170|
# |    2189924|  133|
# |   28993311|  127|
# |   68679869|  125|
# |   32019211|  125|
# |   21959988|  125|
# |   28760509|  123|
# |   45762077|  120|
# |    2988231|  118|
# +-----------+-----+
# only showing top 20 rows

# %%
# faixa etaria media por ano (maior que 2015)
socios\
  .select('cnpj_basico', f.year('data_de_entrada_sociedade').alias('ano_entrada'), 'faixa_etaria', 'cnpj_ou_cpf_do_socio')\
  .groupBy('ano_entrada')\
  .agg(
      f.avg('faixa_etaria').alias('faixa_etaria_media'),
      f.count('cnpj_ou_cpf_do_socio').alias('frequencia')
  )\
  .where('ano_entrada > 2015')\
  .orderBy('ano_entrada', ascending = True)\
  .show()
# Out:
# +-----------+------------------+----------+
# |ano_entrada|faixa_etaria_media|frequencia|
# +-----------+------------------+----------+
# |       2016| 4.802137595450255|     81582|
# |       2017| 4.728178583700026|     90214|
# |       2018| 4.625066293090509|     99894|
# |       2019|4.5248038021784724|    118187|
# |       2020| 4.346581749743899|    125920|
# |       2021| 4.256019603665033|     56311|
# +-----------+------------------+----------+

# %%
estabelecimentos.limit(5).show()
# Out:
# +-----------+----------+-------+---------------------------+-----------------+------------------+-----------------------+-------------------------+--------------------------+----+------------------------+---------------------+----------------------+------------------+--------------------+------+-----------+------------------+-------+---+---------+-----+----------+-----+----------+----------+----+------------------+-----------------+-------------------------+
# |cnpj_basico|cnpj_ordem|cnpj_dv|identificador_matriz_filial|    nome_fantasia|situacao_cadastral|data_situacao_cadastral|motivo_situacao_cadastral|nome_da_cidade_no_exterior|pais|data_de_inicio_atividade|cnae_fiscal_principal|cnae_fiscal_secundaria|tipo_de_logradouro|          logradouro|numero|complemento|            bairro|    cep| uf|municipio|ddd_1|telefone_1|ddd_2|telefone_2|ddd_do_fax| fax|correio_eletronico|situacao_especial|data_da_situacao_especial|
# ...

# %%
# Anos onde mais abriram estabelecimentos (considerando 2018) -> 2020, 2019, 2018, 2021
estabelecimentos.select(f.year('data_de_inicio_atividade').alias('ano_de_inicio'))\
    .where('ano_de_inicio >= 2018')\
    .groupBy('ano_de_inicio')\
    .count()\
    .orderBy('count', ascending=False)\
    .show()
# Out:
# +-------------+------+
# |ano_de_inicio| count|
# +-------------+------+
# |         2020|400654|
# |         2019|325922|
# |         2018|275435|
# |         2021|153275|
# +-------------+------+

# %%
data = [
    ('CARLOS', 'MATEMÁTICA', 7),
    ('IVO', 'MATEMÁTICA', 9),
    ('MÁRCIA', 'MATEMÁTICA', 8),
    ('LEILA', 'MATEMÁTICA', 9),
    ('BRENO', 'MATEMÁTICA', 7),
    ('LETÍCIA', 'MATEMÁTICA', 8),
    ('CARLOS', 'FÍSICA', 2),
    ('IVO', 'FÍSICA', 8),
    ('MÁRCIA', 'FÍSICA', 10),
    ('LEILA', 'FÍSICA', 9),
    ('BRENO', 'FÍSICA', 1),
    ('LETÍCIA', 'FÍSICA', 6),
    ('CARLOS', 'QUÍMICA', 10),
    ('IVO', 'QUÍMICA', 8),
    ('MÁRCIA', 'QUÍMICA', 1),
    ('LEILA', 'QUÍMICA', 10),
    ('BRENO', 'QUÍMICA', 7),
    ('LETÍCIA', 'QUÍMICA', 9)
]
colNames = ['nome', 'materia', 'nota']
df = spark.createDataFrame(data, colNames)
df.show()
# Out:
# +-------+----------+----+
# |   nome|   materia|nota|
# +-------+----------+----+
# | CARLOS|MATEMÁTICA|   7|
# |    IVO|MATEMÁTICA|   9|
# | MÁRCIA|MATEMÁTICA|   8|
# |  LEILA|MATEMÁTICA|   9|
# |  BRENO|MATEMÁTICA|   7|
# |LETÍCIA|MATEMÁTICA|   8|
# | CARLOS|    FÍSICA|   2|
# |    IVO|    FÍSICA|   8|
# | MÁRCIA|    FÍSICA|  10|
# |  LEILA|    FÍSICA|   9|
# |  BRENO|    FÍSICA|   1|
# |LETÍCIA|    FÍSICA|   6|
# | CARLOS|   QUÍMICA|  10|
# |    IVO|   QUÍMICA|   8|
# | MÁRCIA|   QUÍMICA|   1|
# |  LEILA|   QUÍMICA|  10|
# |  BRENO|   QUÍMICA|   7|
# |LETÍCIA|   QUÍMICA|   9|
# +-------+----------+----+

# %%
df = df.withColumn('status', f.when(df.nota >= 7, "APROVADO").otherwise("REPROVADO"))
df.show()
# Out:
# +-------+----------+----+---------+
# |   nome|   materia|nota|   status|
# +-------+----------+----+---------+
# | CARLOS|MATEMÁTICA|   7| APROVADO|
# |    IVO|MATEMÁTICA|   9| APROVADO|
# | MÁRCIA|MATEMÁTICA|   8| APROVADO|
# |  LEILA|MATEMÁTICA|   9| APROVADO|
# |  BRENO|MATEMÁTICA|   7| APROVADO|
# |LETÍCIA|MATEMÁTICA|   8| APROVADO|
# | CARLOS|    FÍSICA|   2|REPROVADO|
# |    IVO|    FÍSICA|   8| APROVADO|
# | MÁRCIA|    FÍSICA|  10| APROVADO|
# |  LEILA|    FÍSICA|   9| APROVADO|
# |  BRENO|    FÍSICA|   1|REPROVADO|
# |LETÍCIA|    FÍSICA|   6|REPROVADO|
# | CARLOS|   QUÍMICA|  10| APROVADO|
# |    IVO|   QUÍMICA|   8| APROVADO|
# | MÁRCIA|   QUÍMICA|   1|REPROVADO|
# |  LEILA|   QUÍMICA|  10| APROVADO|
# |  BRENO|   QUÍMICA|   7| APROVADO|
# |LETÍCIA|   QUÍMICA|   9| APROVADO|
# +-------+----------+----+---------+

# %% [markdown]
# ## Juntando DataFrames - Joins
#
# [DataFrame.join(*args)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.join.html)

# %%
produtos = spark.createDataFrame(
    [
        ('1', 'Bebidas', 'Água mineral'),
        ('2', 'Limpeza', 'Sabão em pó'),
        ('3', 'Frios', 'Queijo'),
        ('4', 'Bebidas', 'Refrigerante'),
        ('5', 'Pet', 'Ração para cães')
    ],
    ['id', 'cat', 'prod']
)

impostos = spark.createDataFrame(
    [
        ('Bebidas', 0.15),
        ('Limpeza', 0.05),
        ('Frios', 0.065),
        ('Carnes', 0.08)
    ],
    ['cat', 'tax']
)

# %%
produtos.toPandas()
# Out:
#   id      cat             prod
# 0  1  Bebidas     Água mineral
# 1  2  Limpeza      Sabão em pó
# 2  3    Frios           Queijo
# 3  4  Bebidas     Refrigerante
# 4  5      Pet  Ração para cães

# %%
impostos.toPandas()
# Out:
#        cat    tax
# 0  Bebidas  0.150
# 1  Limpeza  0.050
# 2    Frios  0.065
# 3   Carnes  0.080

# %%
# .join(argumentos -> dataframe, variavel_de_ligação, como_vou_fazer_a_junção)
# como_vou_fazer_a_junção -> 4 principais

# inner: faz a interseção
# só tem as informações que aparecem nos dois dataframes
produtos.join(impostos, 'cat', how='inner')\
  .sort('id')\
  .show()

# .sort('id')\ # lembra orderBy, mas é mais performático (desvantagem: não garante classificação correta)
# Out:
# +-------+---+------------+-----+
# |    cat| id|        prod|  tax|
# +-------+---+------------+-----+
# |Bebidas|  1|Água mineral| 0.15|
# |Limpeza|  2| Sabão em pó| 0.05|
# |  Frios|  3|      Queijo|0.065|
# |Bebidas|  4|Refrigerante| 0.15|
# +-------+---+------------+-----+

# %%
# left: quero que retorne todas as categorias no dataframe da esquerda
# se não tem referência no da direita aparece 'null'
produtos.join(impostos, 'cat', how='left')\
  .sort('id')\
  .show()
# Out:
# +-------+---+---------------+-----+
# |    cat| id|           prod|  tax|
# +-------+---+---------------+-----+
# |Bebidas|  1|   Água mineral| 0.15|
# |Limpeza|  2|    Sabão em pó| 0.05|
# |  Frios|  3|         Queijo|0.065|
# |Bebidas|  4|   Refrigerante| 0.15|
# |    Pet|  5|Ração para cães| null|
# +-------+---+---------------+-----+

# %%
# right: quero que retorne todas as categorias no dataframe da direita e os que forem compativeis com o df de produtos
produtos.join(impostos, 'cat', how='right')\
  .sort('id')\
  .show()
# Out:
# +-------+----+------------+-----+
# |    cat|  id|        prod|  tax|
# +-------+----+------------+-----+
# | Carnes|null|        null| 0.08|
# |Bebidas|   1|Água mineral| 0.15|
# |Limpeza|   2| Sabão em pó| 0.05|
# |  Frios|   3|      Queijo|0.065|
# |Bebidas|   4|Refrigerante| 0.15|
# +-------+----+------------+-----+

# %%
# outer: união de todos
# se n tem representante fica null
produtos.join(impostos, 'cat', how='outer')\
  .sort('id')\
  .show()
# Out:
# +-------+----+---------------+-----+
# |    cat|  id|           prod|  tax|
# +-------+----+---------------+-----+
# | Carnes|null|           null| 0.08|
# |Bebidas|   1|   Água mineral| 0.15|
# |Limpeza|   2|    Sabão em pó| 0.05|
# |  Frios|   3|         Queijo|0.065|
# |Bebidas|   4|   Refrigerante| 0.15|
# |    Pet|   5|Ração para cães| null|
# +-------+----+---------------+-----+

# %%
# Vendo o que existe em comum entre os dados:
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: date (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %%
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %%
# cnpj_basico é uma dessas ligações
# inner: pega o que existe em comum

empresas_join = estabelecimentos.join(empresas, 'cnpj_basico', how='inner')

# %%
empresas_join.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
# ...

# %%
# distribuição de frequencias segundo o ano de inicio das atividades

freq = empresas_join\
    .select(
        'cnpj_basico',
        f.year('data_de_inicio_atividade').alias('data_de_inicio')
    )\
    .where('data_de_inicio >= 2010')\
    .groupBy('data_de_inicio')\
    .agg(f.count("cnpj_basico").alias("frequencia"))\
    .orderBy('data_de_inicio', ascending=True)

# %%
freq.toPandas()
# Out:
#     data_de_inicio  frequencia
# 0             2010      154159
# 1             2011      172677
# 2             2012      232480
# 3             2013      198424
# 4             2014      202276
# 5             2015      212523
# 6             2016      265417
# 7             2017      237292
# 8             2018      275435
# 9             2019      325922
# 10            2020      400654
# 11            2021      153275

# %%
# colocando um df em cima do outro: utilização do método union
# quero a tabela de cima mas com o somatório total
# f.lit = valor literal (label total)
freq.union(\
           freq.select(
               f.lit('Total').alias('data_de_inicio'),
               f.sum(freq.frequencia).alias('frequencia')
           )
           ).show()
# Out:
# +--------------+----------+
# |data_de_inicio|frequencia|
# +--------------+----------+
# |          2010|    154159|
# |          2011|    172677|
# |          2012|    232480|
# |          2013|    198424|
# |          2014|    202276|
# |          2015|    212523|
# |          2016|    265417|
# |          2017|    237292|
# |          2018|    275435|
# |          2019|    325922|
# |          2020|    400654|
# |          2021|    153275|
# |         Total|   2830534|
# +--------------+----------+

# %%
idades = spark.createDataFrame(
    [
        ('CARLOS', 15),
        ('IVO', 14),
        ('MÁRCIA', 16),
        ('LEILA', 17),
        ('LETÍCIA', 14)
    ],
    ['nomes', 'idades']
)

notas = spark.createDataFrame(
    [
        ('CARLOS', 10),
        ('MÁRCIA', 1),
        ('LEILA', 10),
        ('BRENO', 7),
        ('LETÍCIA', 9)
    ],
    ['nomes', 'notas']
)

# %%
# junta todos os registros
idades.join(notas, 'nomes', how='outer')\
    .sort('nomes')\
    .show()
# Out:
# +-------+------+-----+
# |  nomes|idades|notas|
# +-------+------+-----+
# |  BRENO|  null|    7|
# | CARLOS|    15|   10|
# |    IVO|    14| null|
# |  LEILA|    17|   10|
# |LETÍCIA|    14|    9|
# | MÁRCIA|    16|    1|
# +-------+------+-----+

# %% [markdown]
# ## SparkSQL
#
# [SparkSession.sql(sqlQuery)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.SparkSession.sql.html)
#
# Para saber mais sobre performance: [Artigo - Spark RDDs vs DataFrames vs SparkSQL](https://community.cloudera.com/t5/Community-Articles/Spark-RDDs-vs-DataFrames-vs-SparkSQL/ta-p/246547)
#
# SparkSession possui um método chamado .sql(). Esse método permite que se faça consultas SQL utilizando instruções escritas da maneira padrão. **Para que isso seja possível, é necessário que criar uma view temporária do dataframe, que será usada dentro das instruções SQL em nosso método.**

# %%
# cria a view temporária
# .createOrReplaceTempView recebe como argumento o nome da view
empresas.createOrReplaceTempView('empresasView')

# %%
# a view criada acima repesenta uma tabela
spark.sql("SELECT * FROM empresasView").show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |        306|         FRANCAMAR REFRIGE...|             2240|                         49|                      0.0|               1|                       null|
# |       1355|         BRASILEIRO & OLIV...|             2062|                         49|                      0.0|               5|                       null|
# |       4820|         REGISTRO DE IMOVE...|             3034|                         32|                      0.0|               5|                       null|
# ...

# %%
# deixando mais legível
spark.sql("""
          SELECT *
          FROM empresasView
          WHERE capital_social_da_empresa = 50
          """)\
          .show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |   17350147|         ERIK MARCELO DOS ...|             2135|                         50|                     50.0|               1|                       null|
# |   17833214|         ALEXANDRE MACHADO...|             2135|                         50|                     50.0|               1|                       null|
# |   20860830|         YASMIN MOURA DA F...|             2135|                         50|                     50.0|               1|                       null|
# ...

# %%
spark.sql("""
          SELECT porte_da_empresa, MEAN(capital_social_da_empresa) AS Media
          FROM empresasView
          GROUP BY porte_da_empresa
          """)\
          .show(5)
# Out:
# +----------------+------------------+
# |porte_da_empresa|             Media|
# +----------------+------------------+
# |            null|  8.35421888053467|
# |               1|339994.53313506936|
# |               3|2601001.7677092673|
# |               5| 708660.4208249798|
# +----------------+------------------+

# %%
empresas_join.createOrReplaceTempView('empresasJoinView')

# %%
# fazendo freq e união usando .sql
# criando um novo dataframe de freq
freq = spark\
    .sql("""
        SELECT YEAR(data_de_inicio_atividade) AS data_de_inicio, COUNT(cnpj_basico) AS count
            FROM empresasJoinView
            WHERE YEAR(data_de_inicio_atividade) >= 2010
            GROUP BY data_de_inicio
            ORDER BY data_de_inicio
    """)

freq\
    .show()
# Out:
# +--------------+------+
# |data_de_inicio| count|
# +--------------+------+
# |          2010|154159|
# |          2011|172677|
# |          2012|232480|
# |          2013|198424|
# |          2014|202276|
# |          2015|212523|
# |          2016|265417|
# |          2017|237292|
# |          2018|275435|
# |          2019|325922|
# |          2020|400654|
# |          2021|153275|
# +--------------+------+

# %%
# cria view do dataframe freq
freq.createOrReplaceTempView('freqView')

# %%
# union: método equivalente com .sql
spark\
    .sql("""
        SELECT *
            FROM freqView
        UNION ALL
        SELECT 'Total' AS data_de_inicio, SUM(count) AS count
            FROM freqView
    """)\
    .show()
# Out:
# +--------------+-------+
# |data_de_inicio|  count|
# +--------------+-------+
# |          2010| 154159|
# |          2011| 172677|
# |          2012| 232480|
# |          2013| 198424|
# |          2014| 202276|
# |          2015| 212523|
# |          2016| 265417|
# |          2017| 237292|
# |          2018| 275435|
# |          2019| 325922|
# |          2020| 400654|
# |          2021| 153275|
# |         Total|2830534|
# +--------------+-------+

# %% [markdown]
# # Formas de Armazenamento
# ---

# %% [markdown]
# ## Arquivos CSV
#
# [property DataFrame.write](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrame.write.html)
#
# [DataFrameWriter.csv(*args)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrameWriter.csv.html)

# %%
# cria um novo diretorio na pasta empresas /csv
# overwrite: escreve por cima do que já existe
# separador padrão é ;
# as colunas haviam sido renomeadas nos dataframes, por isso foram salvas com o header=True
empresas.write.csv(
    path='spark/empresas/csv',
    mode='overwrite',
    sep=';',
    header=True
)

# salvou 3 partições automaticamente

# %%
# como fazer a leitura
empresas2 = spark.read.csv('spark/empresas/csv',
                           sep=';',
                           inferSchema=True,
                           header=True) # tb lê o header

# %%
empresas2.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
socios.write.csv(
    path='spark/socios/csv',
    mode='overwrite',
    sep=';',
    header=True
)

# %%
estabelecimentos.write.csv(
    path='spark/estabelecimentos/csv',
    mode='overwrite',
    sep=';',
    header=True
)

# %% [markdown]
# ## Arquivos PARQUET: **formato de armazenamento colunar**
#
# (está disponível para todos os projetos que pertecem ao ecossistema do Hadoop, como o próprio Spark).
#  - Os modelos tradicionais de armazenamento usam a abordagem orientada por linhas;
#
# [Apache Parquet](https://parquet.apache.org/)
#
# [DataFrameWriter.parquet(*args)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrameWriter.parquet.html)
#
# **Vantagens do PARQUET**:
# - A compressão por coluna é mais eficiente;
# - O algoritmo de compressão permite especificar por coluna;
# - Query são mais eficientes tb.
#
# > Existe tb o formato ORC que existe suporte no Spark (write.orc)

# %%
empresas.write.parquet(
    path='spark/empresas/parquet',
    mode='overwrite'
)

# %%
socios.write.parquet(
    path='spark/socios/parquet',
    mode='overwrite'
)

# %%
# Correção de datas invalidas (entradas null) em algumas colunas de dados do dataframe estabelecimentos
# Possibilita salvar no formato parquet
date_cols = [item[0] for item in estabelecimentos.dtypes if item[1].startswith('date')]
for date_col in date_cols:
    estabelecimentos = estabelecimentos.withColumn(date_col,
    f.when(
      f.col(date_col) <= '1900-01-01',
      f.to_date(f.lit('1900-01-01'), 'yyyy-MM-dd'))
    .otherwise(f.col(date_col)))

# %%
estabelecimentos.write.parquet(
    path='spark/estabelecimentos/parquet',
    mode='overwrite'
)

# %%
# fazendo a leitura do parquet
empresas_parquet = spark.read.parquet(
    'spark/empresas/parquet'
)

# %% [markdown]
# ## Particionamento dos dados
#
# [DataFrameWriter.partitionBy(*cols)](https://spark.apache.org/docs/3.1.2/api/python/reference/api/pyspark.sql.DataFrameWriter.partitionBy.html)
#
# Por padrão, se utiliza o Spark em apenas uma máquina (sem cluster configurado), onde as partições são criadas com base no número de cores (núcleos) da CPU. Isso também pode sofrer influência do tamanho do arquivo.
#
# Dependendo do cenário, pode ser interessante criar um arquivo único - por exemplo, para enviá-lo a alguém ou por alguma outra necessidade do negócio. Isso é possível usando alguns recursos do Spark, ainda que seja uma operação que envolve bastante processamento (ou seja, que é considerada "cara").

# %%
# Método coalesce: cria um csv único
# coalesce() é mais perfomático que repartition(), pois apenas diminui o número de partições
empresas.coalesce(1).write.csv(
    path='spark/empresas/csv-unico',
    mode='overwrite',
    sep=';',
    header=True
)

# %%
# Permite o parâmetro partitionBy baseada em uma categoria
# no df empresas tem uma coluna chamada porte_da_empresa que consiste em 4 categorias
# ideia: as partições serão feitas com base nessas categorias
# dentro do novo diretorio criado existem as partições de cada categoria (1, 3 e 5), sendo uma delas nula
empresas.write.parquet(
    path='spark/empresas/parquet-partitionBy',
    mode='overwrite',
        partitionBy='porte_da_empresa'
)

# %%
# Fechando a sessão spark
spark.stop
# Out:
# <bound method SparkSession.stop of <pyspark.sql.session.SparkSession object at 0x7953ff758820>>
